# %%
from modules.lab_8.super_shop import SuperShop
from modules.lab_8.adapter import Adapter

# %%
shop = SuperShop()
adapter = Adapter()

# %%
res = shop.shopping("Adam")
# Out:
# ...
#                  WELCOME ADAM
#                TODAY WE HAVE 48 EGGS
# ...
#
# ...
# ||                  ALL LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_6
# weight: 1580
# color: Golden
# wings len: 3
# price: 865709
# special: Fast_Running
#
#  type: salamandra
# name: Salamandra_2
# weight: 2836
# color: Red
# wings len: 23
# price: 676825
# special: Resistance
#
#  type: salamandra
# name: Salamandra_3
# weight: 3634
# color: Red
# wings len: 18
# price: 639668
# special: Resistance
#
#  type: dinosaur
# name: Dinosaur_7
# weight: 1503
# color: Brown
# wings len: 4
# price: 1677528
# special: Fast_Running
#
#  type: salamandra
# name: Salamandra_4
# weight: 489
# color: Golden
# wings len: 27
# price: 300370
# special: Resistance
#
# ...
# ||                  ALL LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_6
# weight: 1580
# color: Golden
# wings len: 3
# price: 865709
# special: Fast_Running
#
#  type: salamandra
# name: Salamandra_2
# weight: 2836
# ...

# %%
adapter.mas_adapt(res)
# Out:
# [type: dinosaur
#  name: Dinosaur_6
#  weight: 1580
#  color: Golden
#  wings len: 3
#  price: 865709
#  special: Fast_Running,
#  type: cat
#  name: Cat_1
#  weight: 9
#  color: Brown
#  wings len: 0.5
#  price: 5000
#  special: Kawaii,
#  type: salamandra
#  name: Salamandra_3
#  weight: 3634
#  color: Red
#  wings len: 18
#  price: 639668
#  special: Resistance,
#  type: dinosaur
#  name: Dinosaur_7
#  weight: 1503
#  color: Brown
#  wings len: 4
#  price: 1677528
#  special: Fast_Running,
#  type: cat
#  name: Cat_2
#  weight: 9
#  color: Brown
#  wings len: 0.5
#  price: 5000
#  special: Kawaii]
