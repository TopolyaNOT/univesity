# %% [markdown]
# # В таблиці Movies

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Знайдіть назву всіх фільмів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  Exercise 2

# %% [markdown]
# ### Знайдіть директора та рік кожного фільму

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 3

# %% [markdown]
# ### Знайдіть інформацію по кожному з фільмів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Знайдіть фільми Id яких дорівнює 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 5

# %% [markdown]
# ### Знайдіть фільми, що вийшли з 2000 по 2010 рік

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 6

# %% [markdown]
# ## Знайдіть фільми, які були випущені у 2006, 2088, 2010 роках.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 7

# %% [markdown]
# ### Знайдіть фільми та їх директорів, випущені до 2010 року (з використанням NOT)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 8

# %% [markdown]
# ### Знайдіть всі фільми Toy Story

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 9

# %% [markdown]
# ### Знайдіть 2 фільми Toy Story іншим способом

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 10

# %% [markdown]
# ### Знайдіть всі фільми, що були зняті Джоном Лассатером

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 11

# %% [markdown]
# ### Знайдіть всі фільми, що НЕ були зняті Джоном Лассетеро

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 12

# %% [markdown]
# ### Знайдіть всі фільми WALL-*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 13

# %% [markdown]
# ### Виведіть перелік режисерів(без дублювання) в алфавітному порядку

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 14

# %% [markdown]
# ### Перелік з 4 фільмів новійших фільмів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 15

# %% [markdown]
# ### Перелік з 5 фільмів, відсортованих за алфавітом

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 16

# %% [markdown]
# ### Перелік з наступних 5 фільмів, відсортованих за алфавітом

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Для таблиць Movies та Boxoffice, об’єднаних через INNER JOIN:

# %% [markdown]
# ## Exercies 17

# %% [markdown]
# ### Знайдіть внутрішні та міжнародні продажі для кожного фільму

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 18

# %% [markdown]
# ### Покажіть всі фільми з їх рейтингами у спадному порядку

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Далі поєднуйте таблиці так, як Вам буде зручно:

# %% [markdown]
# ## Exercies 19

# %% [markdown]
# ### Виведіть перелік будівель та людей, які живуть у цих будівлях, з їх професіями

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 20

# %% [markdown]
# ### Виведіть перелік людей та їх спеціальностей, які не прикріплені до будинків

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 21

# %% [markdown]
# ### Виведіть всі назви фільмів та їх загальні збори в доларовому еквіваленті

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 22

# %% [markdown]
# ### Виведіть всі фільми та їх рейтинг у відсотках (10 – 100%)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 23

# %% [markdown]
# ### Виведіть всі фільми, які були випущені не раніше 2008 року

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 24

# %% [markdown]
# ## Виведіть всі фільми та середню ціну зборів їх одної хвилини

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 25

# %% [markdown]
# ### Знайдіть робітника з таблиці Employees, який найдовщий час пропрацював у студії

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 26

# %% [markdown]
# ### Для кожної з професій знайдіть середній час роботи спеціалістів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 27

# %% [markdown]
# ### Знайдіть скільки сумарно людино/років витратили на кожній з будівель

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 28

# %% [markdown]
# ### Знайдіть скільки працівників кожної з професій є на підприємстві

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 29

# %% [markdown]
# ### Знайдіть к-сть Дизайнерів у студії, використовуючи HAVING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 30

# %% [markdown]
# ### Знайдіть кількість працівників кожної професії

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 31

# %% [markdown]
# ### Знайдіть к-сть фільмів, знятих кожним з режисерів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 32

# %% [markdown]
# ### Знайдіть загальну кількість зборів по кожному з режисерів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 33

# %% [markdown]
# ### Додайте у список фільмів другу і третю частини трилогії («Володар перстнів 2: дві башти», 2002, 179 хв. та «Володар перстнів 3: повернення короля», 2003, 201 хв.), не вказуючи стовпчики

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 34

# %% [markdown]
# ### Заповніть дані бокс-офісу:
# 1) рейтинг: 9.26, збори в США невідомі, 871530324
# 2) 9.34,-, 925 282 504
# 3) 9.44, -, 1 119 110 941 для нових фільмів

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 35

# %% [markdown]
# ### Насправді фільм “A Bug’s Life” був знятий Джоном Лесеттером. Виправте це

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 36

# %% [markdown]
# ### А фільм “Toy Story 2” був знятий у 1999 році…

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 37

# %% [markdown]
# ### Залишилось виправити фільм “Toy Story 8” – насправді це була 3 частина, і вона була знята Lee Unkrich.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 38

# %% [markdown]
# ### Видаліть всі фільми за 2006 рік

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 39

# %% [markdown]
# ### Видаліть всі фільми режисера Ендрю Стентмена, який покинув студію..

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 40

# %% [markdown]
# ### Створіть нову таблицю з назвою “Database”, та трьома стовпчиками – Name, Version, Download_count. Завчасно подумайте, дані яких типів будуть зберігатись у таких стовпцях. Використайте відповідний SQL-запит.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 41

# %% [markdown]
# ### Додайте в таблицю «Фільми» стовпчик для зберігання дробових чисел Aspect_ratio (співвідношення сторін)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercies 42

# %% [markdown]
# ### Знищіть всі таблиці

# %% [markdown]
# ![image.png](attachment:image.png)
