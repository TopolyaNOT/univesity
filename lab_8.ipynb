# %%
from modules.lab_8.super_shop import SuperShop

# %%
shop = SuperShop()

# %%
shop.shopping("Adam")
# Out:
# ...
#                  WELCOME ADAM
#                TODAY WE HAVE 37 EGGS
# ...
#
# ...
# ||                  ALL LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_9
# weight: 4304
# color: Brown
# wings len: 0
# price: 1646251
# special: Fast_Running
#
#  type: dragon
# name: Dragon_13
# weight: 139
# color: Golden
# wings len: 48
# price: 1113333
# special: Flying
#
# ...
# ||                  NEW LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_10
# weight: 2594
# color: Golden
# wings len: 0
# price: 881353
# special: Fast_Running
#
# Compensation is 548750
#
# ...
# ||                  ALL LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_10
# weight: 2594
# color: Golden
# wings len: 0
# price: 881353
# special: Fast_Running
#
#  type: dragon
# name: Dragon_13
# weight: 139
# color: Golden
# wings len: 48
# price: 1113333
# special: Flying
#
# ...
# ||                  ALL LIZARDS                  ||
# ...
#
#  type: dinosaur
# name: Dinosaur_10
# weight: 2594
# ...
