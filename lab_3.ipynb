# %% [markdown]
# #### Виведіть в консоль результати роботи наступних функцій або процедур. Всі КОРИСТУВАЦЬКІ ФУНКЦІЇ (завдання 1, 3, 4, 6) повинні знаходитись в іншому файлі і визиватись через import:
#
# 1. КОРИСТУВАЦЬКА ФУНКЦІЯ, яка збільшує число у 2 рази, а потім – додає 4.
#
# 2. Процедура, яка просить ввести користувача певне слово, додає до нього знак оклику і виводить це в консоль
#
# 3. КОРИСТУВАЦЬКА ФУНКЦІЯ, яка просить ввести користувача число, виводить «Дякую!» і повертає введене число у основний потік програми
#
# 4. Зробіть простий калькулятор, де кожній операції відповідає окрема КОРИСТУВАЦЬКА ФУНКЦІЯ (користувачу пропонують ввести знак, потім – перше та друге число, після чого користувач отримує результат, який розраховується у користувацькій функції). Якщо користувач вводить слово “exit” – програма завершує роботу). Далі йде шаблон, який потрібно дописати…
#
# 5. Інженерний калькулятор:
#
# Зробимо з Вашого минулого калькулятора інженерний. По аналогії, Ви дописуєте elif до блоку для кожної з кнопок і створюєте відповідний метод (також, окремій операції повинна відповідати окрема функція). Проблема в тому, що математичні методи розрахунку Вам доведеться освоїти самостійно J
#
# Завдання виконується по варіантам з 1 по 3, відносно списку групи.

# %%
from modules.lab_3.operation import double_num
from modules.lab_3.thanks import thanks
from modules.lab_3.calculator import Calculator

# %%
# 1
d = double_num(5)
print(d)

# %%
# 2
def add_exclamation(string: str) -> str:
    return string + "!"

s = add_exclamation("Hello")
print(s)

# %%
# 3
t = thanks(100)
print(t)

# %%
# 4 / 5
C = Calculator()
result = C.calculate()
